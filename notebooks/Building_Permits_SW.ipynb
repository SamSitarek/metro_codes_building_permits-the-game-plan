# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
convert_dict = {'CASE_TYPE': 'category',
                'SUB_TYPE': 'category',
                'STATUS_CODE': 'category',
                'RESULT_CODE': 'category'
               }

# %%
ca = pd.read_csv('../data/Initiated Building Permits (CA Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'], dtype=convert_dict)
fr = pd.read_csv('../data/Initiated Building Permits (FR Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'], dtype=convert_dict)
pl = pd.read_csv('../data/Initiated Building Permits (PL Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'], dtype=convert_dict)
pw = pd.read_csv('../data/Initiated Building Permits (PW Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'], dtype=convert_dict)
sw = pd.read_csv('../data/Initiated Building Permits (SW Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'], dtype=convert_dict)
ws = pd.read_csv('../data/Initiated Building Permits (WS Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'], dtype=convert_dict)
u_o = pd.read_csv('../data/Initiated Building Permits 3yr (Temp-Final U_O).csv',
                 parse_dates=['Date_Initiated','Date_Issued','Temp U&O Complete Date','Final U&O Complete Date'], dtype=convert_dict)
yr3 = pd.read_csv('../data/Initiated Building Permits 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued'], dtype=convert_dict)
# Out:
# C:\Users\Samantha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
u_o = u_o.dropna(subset = ['Final U&O Complete Date'])

# %%
ca = ca[~ca['PERMIT #'].astype(str).str.startswith('T', 'D')]
fr = fr[~fr['PERMIT #'].astype(str).str.startswith('T', 'D')]
pl = pl[~pl['PERMIT #'].astype(str).str.startswith('T', 'D')]
pw = pw[~pw['PERMIT #'].astype(str).str.startswith('T', 'D')]
sw = sw[~sw['PERMIT #'].astype(str).str.startswith('T', 'D')]
ws = ws[~ws['PERMIT #'].astype(str).str.startswith('T', 'D')]
u_o = u_o[~u_o['PERMIT #'].astype(str).str.startswith('T', 'D')]
yr3 = yr3[~yr3['PERMIT #'].astype(str).str.startswith('T', 'D')]

# %%
# "**only do this after running the code in F6 to drop permit #s without final U&O date**
ca_and_uo = pd.merge(ca, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
fr_and_uo = pd.merge(fr, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
pl_and_uo = pd.merge(pl, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
pw_and_uo = pd.merge(pw, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
sw_and_uo = pd.merge(sw, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
ws_and_uo = pd.merge(ws, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-40dbc809d4f5> in <module>
#       1 # "**only do this after running the code in F6 to drop permit #s without final U&O date**
#       2 ca_and_uo = pd.merge(ca, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
# ----> 3 fr_and_uo = pd.merge(fr, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
#       4 pl_and_uo = pd.merge(pl, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
#       5 pw_and_uo = pd.merge(pw, u_o[['PERMIT #', 'Final U&O Complete Date']], how = 'left', on='PERMIT #')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     670         # validate the merge keys dtypes. We may need to coerce
#     671         # to avoid incompatible dtypes
# --> 672         self._maybe_coerce_merge_keys()
#     673
#     674         # If argument passed to validate,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1191                     inferred_right in string_types and inferred_left not in string_types
#    1192                 ):
# -> 1193                     raise ValueError(msg)
#    1194
#    1195             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
ca_permittype = ca.groupby('CASE_TYPE').count()
fr_permittype = fr.groupby('CASE_TYPE').count()
pl_permittype = pl.groupby('CASE_TYPE').count()
pw_permittype = pw.groupby('CASE_TYPE').count()
sw_permittype = sw.groupby('CASE_TYPE').count()
ws_permittype = ws.groupby('CASE_TYPE').count()
# Out:
#       PERMIT # CASE_TYPE                   CASE_TYPE_DESC   SUB_TYPE  \
# 0   2020011891      CARA  Building Residential - Addition  CAA01R301
# 1   2020011891      CARA  Building Residential - Addition  CAA01R301
# 2  T2018000041      CACA   Building Commercial - Addition   ADDITION
# 3  T2018000041      CACA   Building Commercial - Addition   ADDITION
# 4  T2018000649      CARN       Building Residential - New  CAA01R301
#
#              SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage STATUS_CODE  \
# 0  Single Family Residence            25936.0          1236.0        OPEN
# 1  Single Family Residence            25936.0          1236.0        OPEN
# 2                 Addition            33670.0             0.0        DONE
# 3                 Addition            33670.0             0.0        DONE
# 4  Single Family Residence           252865.7          2450.0        DONE
#
#   Date_Initiated Date_Issued TASK_CODE                              TASK_DESC  \
# 0     2020-02-24         NaT   SWGRADE  [D]  Grading Plan Review For Bldg App
# 1     2020-02-24         NaT  SWFLDPLN    [C]  Flood Plain Review On Blgd App
# 2     2018-01-02         NaT   SWGRADE  [D]  Grading Plan Review For Bldg App
# 3     2018-01-02         NaT  SWFLDPLN    [C]  Flood Plain Review On Blgd App
# 4     2018-01-04         NaT   SWGRADE  [D]  Grading Plan Review For Bldg App
#
#   RESULT_CODE                         RESULT_DESC Task_Complete_Date
# 0    APPROVED                            Approved         2020-02-25
# 1      IGNORE  No sign-off needed on this project         2020-02-25
# 2    APPROVED                            Approved         2018-02-08
# 3      IGNORE  No sign-off needed on this project         2018-02-08
# 4    REJECTED                            Rejected         2018-01-04

# %%
sw.tail()
# Out:
#          PERMIT # CASE_TYPE              CASE_TYPE_DESC   SUB_TYPE  \
# 46097  2020068782      CARN  Building Residential - New  CAA14U009
# 46098  2020070844      CARN  Building Residential - New  CAA01R301
# 46099  2020070844      CARN  Building Residential - New  CAA01R301
# 46100  2020070845      CARN  Building Residential - New  CAA01R301
# 46101  2020070845      CARN  Building Residential - New  CAA01R301
#
#                      SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage  \
# 46097  Accessory Structure, Garage           43904.70           909.0
# 46098      Single Family Residence          160279.28          1322.0
# 46099      Single Family Residence          160279.28          1322.0
# 46100      Single Family Residence          160279.28          1322.0
# 46101      Single Family Residence          160279.28          1322.0
#
#       STATUS_CODE Date_Initiated Date_Issued TASK_CODE  \
# 46097       ISSUE     2020-11-02  2021-05-28   SWGRADE
# 46098       ISSUE     2020-11-11  2021-05-29   SWGRADE
# 46099       ISSUE     2020-11-11  2021-05-29  SWFLDPLN
# 46100       ISSUE     2020-11-11  2021-05-29   SWGRADE
# 46101       ISSUE     2020-11-11  2021-05-29  SWFLDPLN
#
#                                    TASK_DESC RESULT_CODE  \
# 46097  [D]  Grading Plan Review For Bldg App        COND
# 46098  [D]  Grading Plan Review For Bldg App        COND
# 46099    [C]  Flood Plain Review On Blgd App      IGNORE
# 46100  [D]  Grading Plan Review For Bldg App        COND
# 46101    [C]  Flood Plain Review On Blgd App      IGNORE
#
#                               RESULT_DESC Task_Complete_Date
# 46097              Approved with Comments         2020-11-04
# 46098              Approved with Comments         2020-12-11
# 46099  No sign-off needed on this project         2020-12-01
# 46100              Approved with Comments         2020-12-11
# 46101  No sign-off needed on this project         2020-12-01

# %%
sw.info
# Out:
# <bound method DataFrame.info of           PERMIT # CASE_TYPE                   CASE_TYPE_DESC   SUB_TYPE  \
# 0       2020011891      CARA  Building Residential - Addition  CAA01R301
# 1       2020011891      CARA  Building Residential - Addition  CAA01R301
# 2      T2018000041      CACA   Building Commercial - Addition   ADDITION
# 3      T2018000041      CACA   Building Commercial - Addition   ADDITION
# 4      T2018000649      CARN       Building Residential - New  CAA01R301
# ...            ...       ...                              ...        ...
# 46097   2020068782      CARN       Building Residential - New  CAA14U009
# 46098   2020070844      CARN       Building Residential - New  CAA01R301
# 46099   2020070844      CARN       Building Residential - New  CAA01R301
# 46100   2020070845      CARN       Building Residential - New  CAA01R301
# 46101   2020070845      CARN       Building Residential - New  CAA01R301
#
#                      SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage  \
# 0          Single Family Residence           25936.00          1236.0
# 1          Single Family Residence           25936.00          1236.0
# 2                         Addition           33670.00             0.0
# 3                         Addition           33670.00             0.0
# 4          Single Family Residence          252865.70          2450.0
# ...                            ...                ...             ...
# 46097  Accessory Structure, Garage           43904.70           909.0
# 46098      Single Family Residence          160279.28          1322.0
# 46099      Single Family Residence          160279.28          1322.0
# 46100      Single Family Residence          160279.28          1322.0
# 46101      Single Family Residence          160279.28          1322.0
#
#       STATUS_CODE Date_Initiated Date_Issued TASK_CODE  \
# 0            OPEN     2020-02-24         NaT   SWGRADE
# 1            OPEN     2020-02-24         NaT  SWFLDPLN
# 2            DONE     2018-01-02         NaT   SWGRADE
# 3            DONE     2018-01-02         NaT  SWFLDPLN
# 4            DONE     2018-01-04         NaT   SWGRADE
# ...           ...            ...         ...       ...
# 46097       ISSUE     2020-11-02  2021-05-28   SWGRADE
# 46098       ISSUE     2020-11-11  2021-05-29   SWGRADE
# 46099       ISSUE     2020-11-11  2021-05-29  SWFLDPLN
# 46100       ISSUE     2020-11-11  2021-05-29   SWGRADE
# 46101       ISSUE     2020-11-11  2021-05-29  SWFLDPLN
#
#                                    TASK_DESC RESULT_CODE  \
# 0      [D]  Grading Plan Review For Bldg App    APPROVED
# 1        [C]  Flood Plain Review On Blgd App      IGNORE
# 2      [D]  Grading Plan Review For Bldg App    APPROVED
# 3        [C]  Flood Plain Review On Blgd App      IGNORE
# 4      [D]  Grading Plan Review For Bldg App    REJECTED
# ...                                      ...         ...
# 46097  [D]  Grading Plan Review For Bldg App        COND
# 46098  [D]  Grading Plan Review For Bldg App        COND
# 46099    [C]  Flood Plain Review On Blgd App      IGNORE
# 46100  [D]  Grading Plan Review For Bldg App        COND
# 46101    [C]  Flood Plain Review On Blgd App      IGNORE
#
#                               RESULT_DESC Task_Complete_Date
# 0                                Approved         2020-02-25
# 1      No sign-off needed on this project         2020-02-25
# 2                                Approved         2018-02-08
# 3      No sign-off needed on this project         2018-02-08
# 4                                Rejected         2018-01-04
# ...                                   ...                ...
# 46097              Approved with Comments         2020-11-04
# 46098              Approved with Comments         2020-12-11
# 46099  No sign-off needed on this project         2020-12-01
# 46100              Approved with Comments         2020-12-11
# 46101  No sign-off needed on this project         2020-12-01
#
# [46102 rows x 15 columns]>

# %%
# Holliday: Have been using this as a way to explore elapsed time:
# for ind, row in sw.iterrows():
#     if row['Date_Issued'] is pd.NaT or row['Date_Issued'] > row['Task_Complete_Date']:
#         pw.loc[ind, 'time_from_init'] = row['Task_Complete_Date'] - row['Date_Initiated']
#     else:
#         pw.loc[ind,'time_from_issue'] = row['Task_Complete_Date'] - row['Date_Issued']

# %%
csv_names = [ca, fr, pl, pw, sw, ws, u_o, yr3]
case_types= []
for item in csv_names:
    case_types.extend(item['CASE_TYPE'].unique().to_list())
print(case_types)
# Out:
# ['CARA', 'CARR', 'CARN', 'CACL', 'CACA', 'CACR', 'CACH', 'CACN', 'CACT', 'CACJ', 'CACK', 'CARP', 'CART', 'CACF', 'CARK', 'CARE', 'CARJ', 'CACE', 'CACG', 'CARS', 'CARL', 'CACS', 'CARF', 'CACP', 'CARH', 'CARA', 'CACA', 'CACR', 'CARN', 'CACH', 'CACN', 'CACK', 'CACT', 'CARR', 'CART', 'CACF', 'CARE', 'CACG', 'CACL', 'CACS', 'CACJ', 'CARF', 'CARS', 'CARJ', 'CACP', 'CARP', 'CARK', 'CARH', 'CARL', 'CACH', 'CACT', 'CACR', 'CACN', 'CACF', 'CARN', 'CARA', 'CACA', 'CARR', 'CACG', 'CACL', 'CARL', 'CACJ', 'CACK', 'CACS', 'CARK', 'CARJ', 'CARP', 'CARE', 'CART', 'CARS', 'CARA', 'CACR', 'CARN', 'CACA', 'CACH', 'CACN', 'CACK', 'CACT', 'CARR', 'CARK', 'CACF', 'CARE', 'CARP', 'CACL', 'CARS', 'CACS', 'CARF', 'CARL', 'CACJ', 'CARJ', 'CACG', 'CARH', 'CART', 'CACP', 'CARA', 'CACA', 'CARN', 'CACR', 'CARR', 'CACH', 'CACN', 'CACJ', 'CACF', 'CACT', 'CARK', 'CACK', 'CARE', 'CACG', 'CACL', 'CARL', 'CARF', 'CACS', 'CARS', 'CACP', 'CARJ', 'CARP', 'CARH', 'CART', 'CACA', 'CACR', 'CARN', 'CACH', 'CACN', 'CACT', 'CACJ', 'CART', 'CACF', 'CARR', 'CARA', 'CACS', 'CARF', 'CACL', 'CARS', 'CACK', 'CACP', 'CARP', 'CACG', 'CARH', 'CARK', 'CARE', 'CARL', 'CARR', 'CACN', 'CACR', 'CARN', 'CACT', 'CARA', 'CACA', 'CACF', 'CACJ', 'CARJ', 'CACH', 'CACL', 'CART', 'CACK', 'CARP', 'CARE', 'CARF', 'CARL', 'CARS', 'CARK', 'CACS', 'CACG', 'CARH', 'CACP', 'CARA', 'CARR', 'CARN', 'CACL', 'CACA', 'CACR', 'CART', 'CACT', 'CACH', 'CACN', 'CACK', 'CACJ', 'CARP', 'CARJ', 'CACF', 'CARK', 'CARE', 'CACG', 'CACE', 'CACS', 'CARS', 'CARL', 'CARF', 'CACP', 'CARH']

# %%
case_types = list(set(case_types))

# %%
case_types
# Out:
# ['CACR',
#  'CARS',
#  'CACA',
#  'CACN',
#  'CARE',
#  'CARR',
#  'CARF',
#  'CACL',
#  'CACF',
#  'CACJ',
#  'CARJ',
#  'CARH',
#  'CARL',
#  'CACP',
#  'CACH',
#  'CACG',
#  'CART',
#  'CACS',
#  'CARA',
#  'CACK',
#  'CARN',
#  'CARP',
#  'CARK',
#  'CACE',
#  'CACT']

# %%
type(case_types)
# Out:
# list

# %%
department = {'ca': 'Codes(CA)',
              'fr': 'Fire Marshal (FR)',
              'pl': 'Planning(PL)',
              'pw': 'Public Works (PW)',
              'sw': 'Storm Water (SW)',
              'ws': 'Water Sewer (WS)'}

df_list=[]

ca_ct = ca[['CASE_TYPE', 'CASE_TYPE_DESC']].copy()
ca_ct['department'] = department['ca']
ca_ct_clean= ca_ct.value_counts().reset_index().drop(columns= [0])

# %%
ca_ct_clean
# Out:
#    CASE_TYPE                            CASE_TYPE_DESC department
# 0       CARN                Building Residential - New  Codes(CA)
# 1       CACR               Building Commercial - Rehab  Codes(CA)
# 2       CARA           Building Residential - Addition  Codes(CA)
# 3       CARR              Building Residential - Rehab  Codes(CA)
# 4       CACT   Building Commercial - Tenant Finish Out  Codes(CA)
# 5       CACN                 Building Commercial - New  Codes(CA)
# 6       CACH               Building Commercial - Shell  Codes(CA)
# 7       CACA            Building Commercial - Addition  Codes(CA)
# 8       CACF          Building Commercial - Foundation  Codes(CA)
# 9       CACK    Building Commercial - Roofing / Siding  Codes(CA)
# 10      CARL   Building Residential Rehab Storm Damage  Codes(CA)
# 11      CACL    Building Commercial Rehab Storm Damage  Codes(CA)
# 12      CARK   Building Residential - Roofing / Siding  Codes(CA)
# 13      CART  Building Residential - Tenant Finish Out  Codes(CA)
# 14      CARS     Building Residential New Storm Damage  Codes(CA)
# 15      CARJ        Building Residential - Fire Damage  Codes(CA)
# 16      CARP  Building Residential - Change Contractor  Codes(CA)
# 17      CACJ         Building Commercial - Fire Damage  Codes(CA)
# 18      CACG    Building Commercial - Structural Frame  Codes(CA)
# 19      CACS      Building Commercial New Storm Damage  Codes(CA)
# 20      CARE       Building Residential - Amend Permit  Codes(CA)
# 21      CACP   Building Commercial - Change Contractor  Codes(CA)
# 22      CARF         Building Residential - Foundation  Codes(CA)
# 23      CARH              Building Residential - Shell  Codes(CA)
# 24      CACE        Building Commercial - Amend Permit  Codes(CA)

# %%
print (ca_ct_clean['CASE_TYPE']['department']['CASE_TYPE_DESC'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-8e224ca1122f> in <module>
# ----> 1 print (ca_ct_clean['CASE_TYPE']['department']['CASE_TYPE_DESC'])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# KeyError: 'department'

# %%
sw['CASE_TYPE'].value_counts()

# %%
case_types.info

# %%
df['delta_task'] = df['Task_Complete_Date'] - df
['Date_Initiated']

# %%
#sw = sw.drop(columns=['SUB_TYPE', 'SUB_TYPE_DESC', 'CONSTRUCTION COST', 'Square Footage'])

# %%
sw

# %%
csv_names = [ca, fr, pl, pw, sw, ws, u_o, yr3]
time= []
# for item in csv_names:
#     case_types.extend(item['CASE_TYPE'].unique().to_list())
# print(case_types)

for item in csv_names:
    csv_names['delta_task']=time.extend(item['Task_Complete_Date']-item['Date_Initiated']).to_list()
time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-ca9da6d6eebf> in <module>
#       6
#       7 for item in csv_names:
# ----> 8     csv_names['delta_task']=time.extend(item['Task_Complete_Date']-item['Date_Initiated']).to_list()
#       9 time
#
# AttributeError: 'NoneType' object has no attribute 'to_list'
