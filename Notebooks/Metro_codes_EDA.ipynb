# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#this is a python magic function to automatically show matplotlib plots
# %matplotlib inline

# %%
ca = pd.read_csv('../data/Initiated Building Permits (CA Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'])
fr = pd.read_csv('../data/Initiated Building Permits (FR Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'])
pl = pd.read_csv('../data/Initiated Building Permits (PL Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'])
pw = pd.read_csv('../data/Initiated Building Permits (PW Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'])
sw = pd.read_csv('../data/Initiated Building Permits (SW Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'])
ws = pd.read_csv('../data/Initiated Building Permits (WS Tasks) 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued','Task_Complete_Date'])
u_o = pd.read_csv('../data/Initiated Building Permits 3yr (Temp-Final U_O).csv',
                 parse_dates=['Date_Initiated','Date_Issued','Temp U&O Complete Date','Final U&O Complete Date'])
yr3 = pd.read_csv('../data/Initiated Building Permits 3yr.csv',
                 parse_dates=['Date_Initiated','Date_Issued'])
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sw.rename(columns = {'PERMIT #': 'permit_id'}, inplace=True)
sw['permit_id'] = sw['permit_id'].astype('str')

# %%
sw.head()
# Out:
#      permit_id CASE_TYPE                   CASE_TYPE_DESC   SUB_TYPE  \
# 0   2020011891      CARA  Building Residential - Addition  CAA01R301
# 1   2020011891      CARA  Building Residential - Addition  CAA01R301
# 2  T2018000041      CACA   Building Commercial - Addition   ADDITION
# 3  T2018000041      CACA   Building Commercial - Addition   ADDITION
# 4  T2018000649      CARN       Building Residential - New  CAA01R301
#
#              SUB_TYPE_DESC  CONSTRUCTION COST  Square Footage STATUS_CODE  \
# 0  Single Family Residence            25936.0          1236.0        OPEN
# 1  Single Family Residence            25936.0          1236.0        OPEN
# 2                 Addition            33670.0             0.0        DONE
# 3                 Addition            33670.0             0.0        DONE
# 4  Single Family Residence           252865.7          2450.0        DONE
#
#   Date_Initiated Date_Issued TASK_CODE                              TASK_DESC  \
# 0     2020-02-24         NaT   SWGRADE  [D]  Grading Plan Review For Bldg App
# 1     2020-02-24         NaT  SWFLDPLN    [C]  Flood Plain Review On Blgd App
# 2     2018-01-02         NaT   SWGRADE  [D]  Grading Plan Review For Bldg App
# 3     2018-01-02         NaT  SWFLDPLN    [C]  Flood Plain Review On Blgd App
# 4     2018-01-04         NaT   SWGRADE  [D]  Grading Plan Review For Bldg App
#
#   RESULT_CODE                         RESULT_DESC Task_Complete_Date
# 0    APPROVED                            Approved         2020-02-25
# 1      IGNORE  No sign-off needed on this project         2020-02-25
# 2    APPROVED                            Approved         2018-02-08
# 3      IGNORE  No sign-off needed on this project         2018-02-08
# 4    REJECTED                            Rejected         2018-01-04

# %%
sw = sw.drop(columns=['SUB_TYPE', 'SUB_TYPE_DESC', 'CONSTRUCTION COST', 'Square Footage'])

# %%
sw.head()
# Out:
#      permit_id CASE_TYPE                   CASE_TYPE_DESC STATUS_CODE  \
# 0   2020011891      CARA  Building Residential - Addition        OPEN
# 1   2020011891      CARA  Building Residential - Addition        OPEN
# 2  T2018000041      CACA   Building Commercial - Addition        DONE
# 3  T2018000041      CACA   Building Commercial - Addition        DONE
# 4  T2018000649      CARN       Building Residential - New        DONE
#
#   Date_Initiated Date_Issued TASK_CODE                              TASK_DESC  \
# 0     2020-02-24         NaT   SWGRADE  [D]  Grading Plan Review For Bldg App
# 1     2020-02-24         NaT  SWFLDPLN    [C]  Flood Plain Review On Blgd App
# 2     2018-01-02         NaT   SWGRADE  [D]  Grading Plan Review For Bldg App
# 3     2018-01-02         NaT  SWFLDPLN    [C]  Flood Plain Review On Blgd App
# 4     2018-01-04         NaT   SWGRADE  [D]  Grading Plan Review For Bldg App
#
#   RESULT_CODE                         RESULT_DESC Task_Complete_Date
# 0    APPROVED                            Approved         2020-02-25
# 1      IGNORE  No sign-off needed on this project         2020-02-25
# 2    APPROVED                            Approved         2018-02-08
# 3      IGNORE  No sign-off needed on this project         2018-02-08
# 4    REJECTED                            Rejected         2018-01-04

# %%
for ind, row in sw.iterrows():
    if row['Date_Issued'] is pd.NaT or row['Date_Issued'] > row['Task_Complete_Date']:
        sw.loc[ind, 'time_from_init'] = row['Task_Complete_Date'] - row['Date_Initiated']
    else:
        sw.loc[ind,'time_from_issue'] = row['Task_Complete_Date'] - row['Date_Issued']

# %%
sw.sort_values(by = 'RESULT_CODE').head(50)
# Out:
#         permit_id CASE_TYPE                           CASE_TYPE_DESC  \
# 0      2020011891      CARA          Building Residential - Addition
# 25291  2019053815      CARN               Building Residential - New
# 25290  2019054670      CARN               Building Residential - New
# 25289  2019054670      CARN               Building Residential - New
# 25288  2019053813      CARN               Building Residential - New
# 25287  2019053813      CARN               Building Residential - New
# 25286  2019047743      CACT  Building Commercial - Tenant Finish Out
# 25285  2019036499      CACR              Building Commercial - Rehab
# 25284  2019055728      CARA          Building Residential - Addition
# 25281  2019054340      CACR              Building Commercial - Rehab
# 25280  2019043733      CARA          Building Residential - Addition
# 25278  2019041299      CACR              Building Commercial - Rehab
# 25277  2019016017      CACN                Building Commercial - New
# 25275  2019016017      CACN                Building Commercial - New
# 25274  2019053590      CARA          Building Residential - Addition
# 25272  2019055064      CARA          Building Residential - Addition
# 25269  2019051974      CARA          Building Residential - Addition
# 25268  2019056258      CARA          Building Residential - Addition
# 25266  2019056230      CARA          Building Residential - Addition
# 25265  2019054123      CARN               Building Residential - New
# 25260  2019054150      CARN               Building Residential - New
# 25259  2019051864      CARN               Building Residential - New
# 25256  2019051857      CARN               Building Residential - New
# 25253  2019041406      CARN               Building Residential - New
# 25252  2019056262      CARA          Building Residential - Addition
# 25250  2019056113      CARN               Building Residential - New
# 25236  2019053717      CARN               Building Residential - New
# 25231  2019053710      CARN               Building Residential - New
# 25230  2019056260      CARN               Building Residential - New
# 25229  2019055081      CARA          Building Residential - Addition
# 25292  2019053815      CARN               Building Residential - New
# 25293  2019053817      CARN               Building Residential - New
# 25294  2019053817      CARN               Building Residential - New
# 25295  2019053819      CARN               Building Residential - New
# 25343  2019056401      CARN               Building Residential - New
# 25342  2019056408      CARN               Building Residential - New
# 25339  2019056435      CACK   Building Commercial - Roofing / Siding
# 25338  2019056771      CARA          Building Residential - Addition
# 25337  2019056422      CARA          Building Residential - Addition
# 25335  2019056717      CARN               Building Residential - New
# 25334  2019053100      CACT  Building Commercial - Tenant Finish Out
# 25333  2019056068      CACR              Building Commercial - Rehab
# 25332  2019056068      CACR              Building Commercial - Rehab
# 25331  2019056031      CARN               Building Residential - New
# 25328  2019050206      CACA           Building Commercial - Addition
# 25324  2019031269      CACR              Building Commercial - Rehab
# 25323  2019031269      CACR              Building Commercial - Rehab
# 25322  2019056432      CACR              Building Commercial - Rehab
# 25226  2019047163      CACR              Building Commercial - Rehab
# 25321  2019056432      CACR              Building Commercial - Rehab
#
#       STATUS_CODE Date_Initiated Date_Issued TASK_CODE  \
# 0            OPEN     2020-02-24         NaT   SWGRADE
# 25291        DONE     2019-09-06  2019-09-17   SWGRADE
# 25290        DONE     2019-09-10  2019-09-17  SWFLDPLN
# 25289        DONE     2019-09-10  2019-09-17   SWGRADE
# 25288        DONE     2019-09-06  2019-09-17  SWFLDPLN
# 25287        DONE     2019-09-06  2019-09-17   SWGRADE
# 25286       ISSUE     2019-08-08  2019-09-17  SWFLDPLN
# 25285        DONE     2019-06-20  2019-09-17   SWGRADE
# 25284       ISSUE     2019-09-13  2019-09-17   SWGRADE
# 25281       ISSUE     2019-09-09  2019-09-17   SWGRADE
# 25280        DONE     2019-07-23  2019-09-17  SWUGRADE
# 25278        DONE     2019-07-12  2019-09-17   SWGRADE
# 25277        DONE     2019-03-19  2019-09-17  SWFLDPLN
# 25275        DONE     2019-03-19  2019-09-17  SWUGRADE
# 25274       ISSUE     2019-09-05  2019-09-17   SWGRADE
# 25272       ISSUE     2019-09-11  2019-09-17  SWUGRADE
# 25269        DONE     2019-08-28  2019-09-17   SWGRADE
# 25268       ISSUE     2019-09-17  2019-09-17   SWGRADE
# 25266       ISSUE     2019-09-17  2019-09-17   SWGRADE
# 25265        DONE     2019-09-09  2019-09-17  SWUGRADE
# 25260        DONE     2019-09-09  2019-09-17  SWUGRADE
# 25259        DONE     2019-08-28  2019-09-17  SWUGRADE
# 25256        DONE     2019-08-28  2019-09-17  SWUGRADE
# 25253       ISSUE     2019-07-12  2019-09-17   SWGRADE
# 25252       ISSUE     2019-09-17  2019-09-17   SWGRADE
# 25250       ISSUE     2019-09-16  2019-09-17  SWUGRADE
# 25236       ISSUE     2019-09-05  2019-09-17  SWUGRADE
# 25231       ISSUE     2019-09-05  2019-09-17  SWUGRADE
# 25230        DONE     2019-09-17  2019-09-17   SWGRADE
# 25229       ISSUE     2019-09-11  2019-09-17   SWGRADE
# 25292        DONE     2019-09-06  2019-09-17  SWFLDPLN
# 25293        DONE     2019-09-06  2019-09-17   SWGRADE
# 25294        DONE     2019-09-06  2019-09-17  SWFLDPLN
# 25295        DONE     2019-09-06  2019-09-17   SWGRADE
# 25343       ISSUE     2019-09-17  2019-09-18  SWUGRADE
# 25342        DONE     2019-09-17  2019-09-18  SWUGRADE
# 25339       ISSUE     2019-09-17  2019-09-18  SWFLDPLN
# 25338       ISSUE     2019-09-18  2019-09-18   SWGRADE
# 25337       ISSUE     2019-09-17  2019-09-18   SWGRADE
# 25335       ISSUE     2019-09-18  2019-09-18   SWGRADE
# 25334       ISSUE     2019-09-04  2019-09-18  SWFLDPLN
# 25333       ISSUE     2019-09-16  2019-09-18  SWFLDPLN
# 25332       ISSUE     2019-09-16  2019-09-18   SWGRADE
# 25331        DONE     2019-09-16  2019-09-18  SWUGRADE
# 25328       ISSUE     2019-08-20  2019-09-18   SWGRADE
# 25324        DONE     2019-05-29  2019-09-18  SWFLDPLN
# 25323        DONE     2019-05-29  2019-09-18   SWGRADE
# 25322        DONE     2019-09-17  2019-09-17  SWFLDPLN
# 25226       ISSUE     2019-08-07  2019-09-17   SWGRADE
# 25321        DONE     2019-09-17  2019-09-17   SWGRADE
#
#                                    TASK_DESC RESULT_CODE RESULT_DESC  \
# 0      [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25291  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25290    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25289  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25288    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25287  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25286    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25285  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25284  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25281  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25280                      SWGR U&O Sign-off    APPROVED    Approved
# 25278  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25277    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25275                      SWGR U&O Sign-off    APPROVED    Approved
# 25274  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25272                      SWGR U&O Sign-off    APPROVED    Approved
# 25269  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25268  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25266  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25265                      SWGR U&O Sign-off    APPROVED    Approved
# 25260                      SWGR U&O Sign-off    APPROVED    Approved
# 25259                      SWGR U&O Sign-off    APPROVED    Approved
# 25256                      SWGR U&O Sign-off    APPROVED    Approved
# 25253  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25252  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25250                      SWGR U&O Sign-off    APPROVED    Approved
# 25236                      SWGR U&O Sign-off    APPROVED    Approved
# 25231                      SWGR U&O Sign-off    APPROVED    Approved
# 25230  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25229  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25292    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25293  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25294    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25295  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25343                      SWGR U&O Sign-off    APPROVED    Approved
# 25342                      SWGR U&O Sign-off    APPROVED    Approved
# 25339    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25338  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25337  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25335  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25334    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25333    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25332  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25331                      SWGR U&O Sign-off    APPROVED    Approved
# 25328  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25324    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25323  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25322    [C]  Flood Plain Review On Blgd App    APPROVED    Approved
# 25226  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
# 25321  [D]  Grading Plan Review For Bldg App    APPROVED    Approved
#
#       Task_Complete_Date time_from_init time_from_issue
# 0             2020-02-25         1 days             NaT
# 25291         2019-09-06         0 days             NaT
# 25290         2019-09-10         0 days             NaT
# 25289         2019-09-10         0 days             NaT
# 25288         2019-09-06         0 days             NaT
# 25287         2019-09-06         0 days             NaT
# 25286         2019-08-28        20 days             NaT
# 25285         2019-06-20         0 days             NaT
# 25284         2019-09-13         0 days             NaT
# 25281         2019-09-09         0 days             NaT
# 25280         2021-02-24            NaT        526 days
# 25278         2019-07-12         0 days             NaT
# 25277         2019-06-18        91 days             NaT
# 25275         2021-02-19            NaT        521 days
# 25274         2019-09-17            NaT          0 days
# 25272         2020-06-19            NaT        276 days
# 25269         2019-08-28         0 days             NaT
# 25268         2019-09-17            NaT          0 days
# 25266         2019-09-17            NaT          0 days
# 25265         2020-10-19            NaT        398 days
# 25260         2021-05-07            NaT        598 days
# 25259         2020-10-02            NaT        381 days
# 25256         2020-10-19            NaT        398 days
# 25253         2019-09-17            NaT          0 days
# 25252         2019-09-17            NaT          0 days
# 25250         2020-08-12            NaT        330 days
# 25236         2021-01-08            NaT        479 days
# 25231         2021-01-08            NaT        479 days
# 25230         2019-09-17            NaT          0 days
# 25229         2019-09-12         1 days             NaT
# 25292         2019-09-06         0 days             NaT
# 25293         2019-09-06         0 days             NaT
# 25294         2019-09-06         0 days             NaT
# 25295         2019-09-06         0 days             NaT
# 25343         2020-04-21            NaT        216 days
# 25342         2020-05-05            NaT        230 days
# 25339         2019-09-18            NaT          0 days
# 25338         2019-09-18            NaT          0 days
# 25337         2019-09-17         0 days             NaT
# 25335         2019-09-18            NaT          0 days
# 25334         2019-09-04         0 days             NaT
# 25333         2019-09-16         0 days             NaT
# 25332         2019-09-16         0 days             NaT
# 25331         2020-05-01            NaT        226 days
# 25328         2019-08-20         0 days             NaT
# 25324         2019-09-12       106 days             NaT
# 25323         2019-09-12       106 days             NaT
# 25322         2019-09-17            NaT          0 days
# 25226         2019-08-07         0 days             NaT
# 25321         2019-09-17            NaT          0 days
